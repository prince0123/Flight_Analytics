# %% [markdown]
# # 📊 Crew Manpower Planning & Optimization Dashboard
# ## End-to-End Analytics Project (SQL + Power BI)

# %% [markdown]
# # 1️⃣ Project Overview

# %% [markdown]
# # Objective:
# To analyze crew manpower utilization, roster efficiency, and standby effectiveness in airline operations, and identify actionable opportunities to reduce crew shortages without increasing headcount.
#
# This project simulates a real-world airline operations scenario, focusing on:
#
# Crew planning
#
# Standby utilization
#
# Roster efficiency
#
# Operational risk (OTP & shortages)

# %% [markdown]
# # 2️⃣ Business Problem Statement

# %% [markdown]
# # Airline operations frequently experience:
#
# Crew shortages despite having standby crew
#
# Low on-time performance (OTP)
#
# Increased fatigue and compliance risk
#
# The leadership challenge:
#
# Are crew shortages caused by insufficient manpower, or by inefficient utilization and rostering?
#
# This project answers that question using data-driven analysis.

# %% [markdown]
# # 3️⃣ Data Sources & Dataset Design

# %% [markdown]
# ## The dataset was synthetically generated to mirror real airline operations with realistic volumes and complexity (~50,000+ records).

# %% [markdown]
# ### Key Tables
#
# Table Name	Description
#
# flight_roster_plan	Crew duty assignments (Flying / Standby / Off)
#
# flight_standby_utilization	Standby crew usage (Used vs Unused)
#
# flight_flight_operations	Planned vs actual flight operations
#
# flight_demand_forecast	Planned flights demand
#
# flight_crew_master	Crew attributes
#
# flight_dim_date	Calendar dimension

# %% [markdown]
# # 4️⃣ Data Model

# %% [markdown]
# Star-schema based model with flight_dim_date as the central date dimension.
#
# ### Key relationships:
#
# flight_dim_date[Date] → fact tables (Date)
#
# One-to-many relationships
#
# Single-direction filtering for performance and clarity
#
# ⚠️ A critical learning: activating inactive date relationships was necessary for correct time-based visuals — a common real-world Power BI issue.

# %% [markdown]
# # 5️⃣ KPIs Defined

# %% [markdown]
# # Executive-Level KPIs (Page 1)
#
# ### KPI	Definition
#
# Crew Utilization %	% of active crew deployed
#
# OTP %	% of flights departing within 15 minutes
#
# Flights per Crew	Avg flights handled per crew
#
# Crew Gap	Difference between required and deployed crew
#
# Crew Status	Shortage / Balanced / Surplus
#
# Operational KPIs (Page 2)
#
# KPI	Definition
#
# Standby Utilization %	% of standby crew actually used
#
# Avg Unused Standby	Avg daily unused standby crew
#
# Flying %	% of crew assigned to flying duties
#
# High Risk Days	Days with significant crew shortages

# %% [markdown]
# # 6️⃣ Key Analysis & Insights
# ## 🔍 Page 1 – Executive Summary

# %% [markdown]
# ### Overall crew utilization ~70%
#
# OTP ~75%
#
# Persistent crew shortages observed
#
# Indicates structural planning inefficiencies

# %% [markdown]
# ## 🔍 Page 2 – Roster & Standby Optimization
# ### 🔹 Key Insight 1: Standby Inefficiency

# %% [markdown]
# Only ~54% of standby crew are utilized
#
# Average 9 unused standby crew per day
#
# ➡️ Indicates under-activation of available standby, not lack of manpower.

# %% [markdown]
# ### 🔹 Key Insight 2: Shortage Despite Availability

# %% [markdown]
# ### Used vs unused standby analysis shows unused capacity even on high-risk days
#
# Suggests opportunity for :
#
# Better real-time crew activation
#
# Improved short-term roster optimization

# %% [markdown]
# ### 🔹 Key Insight 3: Operational Risk

# %% [markdown]
# 366 high-risk days detected
#
# Risk linked to fatigue, compliance, and OTP degradation

# %% [markdown]
# # 7️⃣ Business Recommendations

# %% [markdown]
# ### Based on the analysis:
#
# 1️⃣ Optimize Standby Activation
#
# Improve real-time decisioning to deploy available standby crew
#
# 2️⃣ Roster Rebalancing
#
# Reduce non-flying assignments during peak demand periods
#
# 3️⃣ Risk-Based Planning
#
# Use high-risk day identification to proactively adjust staffing
#
# 4️⃣ Avoid Headcount Increase
#
# Address utilization gaps before adding manpower

# %% [markdown]
# # 8️⃣ Tools & Technologies Used

# %% [markdown]
# Tool	Purpose
# SQL	Data modeling, KPI calculation
# Power BI	Data modeling, DAX, dashboards
# DAX	Advanced measures, time intelligence
# Star Schema	Scalable analytical model

# %% [markdown]
# # 9️⃣ Key Technical Challenges Solved

# %% [markdown]
# Handling date format mismatches (SQL vs Power BI)
#
# Avoiding double counting due to granular standby records
#
# Fixing inactive relationships
#
# Designing KPIs at correct data grain
#
# Building executive-friendly tooltips

# %% [markdown]
# # 🔟 Final Outcome

# %% [markdown]
# ###  This project demonstrates:

# %% [markdown]
# End-to-end analytics ownership
#
# Strong understanding of operations & manpower planning
#
# Ability to translate data into business actions
#
# Readiness for analytics roles in large-scale operations
